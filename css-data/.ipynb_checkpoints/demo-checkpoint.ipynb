# %%
pip install ultralytics
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#                                               0.0/663.2 kB ? eta -:--:--
#      ----                                    71.7/663.2 kB 1.9 MB/s eta 0:00:01
#      ---------                              174.1/663.2 kB 2.1 MB/s eta 0:00:01
#      ------------------                     317.4/663.2 kB 2.2 MB/s eta 0:00:01
#      --------------------------------       563.2/663.2 kB 3.2 MB/s eta 0:00:01
#      -------------------------------------- 663.2/663.2 kB 3.2 MB/s eta 0:00:00
# ...
#                                               0.0/38.1 MB ? eta -:--:--
#                                               0.5/38.1 MB 10.5 MB/s eta 0:00:04
#                                               0.9/38.1 MB 9.6 MB/s eta 0:00:04
#      -                                        1.5/38.1 MB 10.5 MB/s eta 0:00:04
#      --                                       2.1/38.1 MB 11.0 MB/s eta 0:00:04
# ...

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')

# %%
model.train(data='demo.yaml',epochs=100)
# Out:
# Ultralytics YOLOv8.0.231 🚀 Python-3.11.3 torch-2.1.2+cpu CPU (AMD Ryzen 7 4800H with Radeon Graphics)
# ...
